# %%
"""
Authored By: Buz Galbraith

"""

import pandas as pd
import numpy as np
import json
from PlaceAndShootGym import *
class StateTraceParser:
    def __init__(self, path):
        """ 1. data is just the json dictionary
            2. position_time is a dictionary with key values for each time step related to the bals position. 
            3. velocity_time dictionary with time keys and velcoity values 
            4.object_position_time dictionary with time keys and object position values
            5.note_times dictionary with time keys and binary variable for if a note is posted
            6.reset_times dictionary with time keys and binary variable for if a reset is made
            7.lastStepNum the final time step 
            8. walls a nested dict with keys X and Y and sub keys max and min representing the game boundry
            9. df time indexed aggreagate dictioanry . 
            10. wall_hits subset of df where the ball hits walls. 
            11. not_wall_hits subset of df where teh ball does not hit the wall 9is the complement of wall hits)
        """
        self.data = json.load(open(path))
        self.obj_tags = self.data["foundObjectsTags"]
        self.colision_tags=self.data["foundCollidersTags"]
        self.dim = len(self.obj_tags)
        self.lastStepNum = self.data["lastStepNum"]
        self.walls = {"X": {"Max": self.data["boxMaxX"],
                            "Min": self.data["boxMinX"]},
                      "Y": {"Max": self.data["boxMaxY"],
                            "Min": self.data["boxMinY"]}}
        self.make_df()

        self.wall_hits = self.df[[self.row_check(
            i) for i in range(len(self.df["ball_x"]))]]
        self.not_wall_hits = self.df[[self.row_check(
            i) == False for i in range(len(self.df["ball_x"]))]]
        self.above_bucket = self.df[self.df["ball_y"] >= self.df["bucket_y"]]
        self.above_corner = self.df[self.df["ball_y"] >= self.df["corner_y"]]
        self.above_triangle = self.df[self.df["ball_y"]
                                      >= self.df["triangle_y"]]
        self.above_gear = self.df[self.df["ball_y"] >= self.df["gear_y"]]
        self.above_crate = self.df[self.df["ball_y"] >= self.df["crate_y"]]
        
        self.obs_vector=[]
        cols = ['bucket_x','bucket_y','corner_x','corner_y','crate_x','crate_y','gear_x','gear_y','triangle_x','triangle_y'\
                ,'ball_x','ball_y', 'velocity_x','velocity_y','reset','collisons']
        for i in range(self.lastStepNum):
            self.obs_vector.append(self.df[cols].iloc[i])

    def make_df(self):
        def makeDict(posVec):
            dct = {}
            for i in range(self.dim):
                dct.update({f"{self.obj_tags[i]}_x": posVec[i]["x"],
                            f"{self.obj_tags[i]}_y": posVec[i]["y"]})
            return dct
        reshaped = [makeDict(self.data["objectPositions"][i:i+self.dim]) for i
                    in range(0, len(self.data["objectPositions"]), self.dim)]
        objPos = pd.DataFrame(reshaped)
        ballPos = pd.DataFrame(self.data["ballPositions"])[["x", "y"]]
        ballPos.columns = ["ball_x", "ball_y"]
        self.df = pd.concat((ballPos, objPos), axis=1)
        if len(self.data["velocitiesCT"])>0:
            self.df.loc[self.data["velocitiesCT"], ["velocity_x", "velocity_y"]] = list(zip(pd.DataFrame(self.data["velocities"])["x"], pd.DataFrame(self.data["velocities"])["y"]))
        else:
            self.df[["velocity_x", "velocity_y"]] = 0.0
        self.df.loc[self.data["resetCT"], "reset"] = 1
        self.df.loc[self.data["notesCT"], "note_taken"] = 1
        self.df.fillna(0, inplace=True)
        self.df["collisons"]=np.zeros([self.lastStepNum])
        for i in range(len(self.data["ballCollisions"])):
            self.df["collisons"][self.data["ballCollisionsCT"][i]]=self.data["ballCollisions"][i]
        

    def row_check(self, x): 
        return (self.df["ball_x"][x] <= self.walls["X"]["Min"]) or \
                (self.df["ball_x"][x] >= self.walls["X"]["Max"]) or \
                (self.df["ball_y"][x] <= self.walls["Y"]["Min"]) or \
                (self.df["ball_y"][x] >= self.walls["Y"]["Max"])

    def ballInBucket(self, timestep):
        MIN_X_DELTA = -0.1927506923675537
        MAX_X_DELTA = 0.2523689270019531
        MIN_Y_DELTA = -0.24334418773651123
        MAX_Y_DELTA = 0.6142134666442871

        x_delta = self.df.loc[timestep, "ball_x"] - self.df.loc[timestep, "bucket_x"]
        y_delta = self.df.loc[timestep, "ball_y"] - self.df.loc[timestep, "bucket_y"]

        return (MAX_X_DELTA>=x_delta>=MIN_X_DELTA) and (MAX_Y_DELTA>=y_delta>=MIN_Y_DELTA)

# %%
# path=r"C:\Users\buz galbraith\Desktop\School\Advanced Topics in DS\project work\Experimenter_View_25April22_Windows\Object Physics Sandbox_Data\InteractionLogs\logs_2022_04_27_22_59_36_buz.json"
# run=StateTraceParser(path)
run.obs_vector
# Out:
# [bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 0, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 1, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 2, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 3, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 4, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 5, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 6, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 7, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 8, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 9, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 10, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 11, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 12, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 13, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 14, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 15, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 16, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 17, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 18, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 19, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 20, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 21, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 22, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 23, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 24, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 25, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 26, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 27, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 28, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 29, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 30, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 31, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 32, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 33, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 34, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 35, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 36, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 37, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 38, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 39, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 40, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 41, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 42, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 43, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 44, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 45, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 46, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 47, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 48, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 49, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 50, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 51, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 52, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 53, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 54, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 55, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 56, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 57, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 58, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 59, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 60, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 61, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 62, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 63, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 64, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 65, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 66, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 67, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 68, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 69, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 70, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 71, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 72, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 73, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 74, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 75, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 76, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 77, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 78, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 79, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 80, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 81, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 82, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 83, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 84, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 85, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 86, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 87, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 88, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 89, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 90, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 91, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 92, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 93, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 94, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 95, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 96, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 97, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 98, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 99, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 100, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 101, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 102, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 103, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 104, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 105, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 106, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 107, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 108, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 109, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 110, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 111, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 112, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 113, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 114, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 115, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 116, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 117, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 118, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 119, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 120, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 121, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 122, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 123, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 124, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 125, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 126, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 127, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 128, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 129, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 130, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 131, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 132, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 133, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 134, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 135, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 136, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
#  crate_x       6.75
#  crate_y       2.50
#  gear_x        6.75
#  gear_y       -0.65
#  triangle_x    6.75
#  triangle_y   -2.00
#  ball_x        0.00
#  ball_y       -3.90
#  velocity_x    0.00
#  velocity_y    0.00
#  reset         0.00
#  collisons     0.00
#  Name: 137, dtype: float64,
#  bucket_x      6.75
#  bucket_y      1.00
#  corner_x      6.75
#  corner_y     -3.50
# ...
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    6.039125e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 966, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    6.029100e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 967, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    6.019092e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 968, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    6.009100e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 969, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.999124e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 970, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.989165e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 971, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.979223e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 972, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.969298e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 973, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.959389e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 974, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.949496e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 975, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.939619e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 976, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.929759e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 977, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.919915e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 978, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.910088e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 979, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.900278e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 980, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.890483e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 981, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.880704e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 982, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.870942e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 983, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.861196e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 984, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.851466e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 985, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.841752e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 986, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.832055e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 987, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.822374e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 988, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.812709e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 989, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.803059e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 990, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.793426e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 991, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.783809e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 992, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.774207e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 993, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.764622e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 994, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.755053e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 995, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.745499e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 996, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.735961e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 997, dtype: float64,
#  bucket_x      6.750000e+00
#  bucket_y      1.000000e+00
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.726440e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 998, dtype: float64,
#  bucket_x      6.845778e+00
#  bucket_y      4.506943e-01
#  corner_x     -2.690917e+00
#  corner_y     -2.157324e+00
#  crate_x       6.750000e+00
#  crate_y       2.500000e+00
#  gear_x        7.223420e-01
#  gear_y        1.394148e+00
#  triangle_x   -3.700472e+00
#  triangle_y   -2.145305e+00
#  ball_x       -3.363954e+00
#  ball_y       -3.933516e+00
#  velocity_x    5.716933e-07
#  velocity_y    0.000000e+00
#  reset         0.000000e+00
#  collisons     0.000000e+00
#  Name: 999, dtype: float64,
#  ...]
